# %%
# %matplotlib inline
# not sure if necessary

# %%
import finetune
import importlib
import torch

# %%
# run this cell when you change stuff in the finetune module, and don't want to restart the notebook's kernel.
importlib.reload(finetune)
# Out:
# <module 'finetune' from 'C:\\Users\\dylan\\PycharmProjects\\REDI-utwente\\src\\awesome_GNN\\finetune.py'>

# %%
# Loading certain model
# model_props = {
#     'name': 'resnet',
#     'dataset': 'StanfordCars',
#     'epochs': 30
# }
# model_load_path = finetune.format_model_path(model_props['name'],
#                                              model_props['dataset'],
#                                              model_props['epochs'])
# ,
# state = torch.load(model_load_path)
# model = finetune.get_model_architecture(model_props['name'])
# model.load_state_dict(state['model_state_dict'])
# optimizer_state_dict = state['optimizer_state_dict']

# %%
model_props = {
    'name': 'resnet',
    'dataset': 'StanfordCars',
    'epochs': 30
}
model_load_path = finetune.format_model_path(model_props['name'],
                                             model_props['dataset'],
                                             model_props['epochs'])

checkpoint = finetune.load_checkpoint(model_load_path)
finetune.get_information_from_checkpoint(checkpoint, plot=True)
# Out:
# ([0.047274066797642435,
#   0.16666666666666666,
#   0.1942534381139489,
#   0.3492537313432836,
#   0.3236738703339882,
#   0.4761194029850746,
#   0.4347986247544204,
#   0.5805970149253731,
#   0.5212426326129665,
#   0.645273631840796,
#   0.5855844793713163,
#   0.6990049751243781,
#   0.6419449901768173,
#   0.7393034825870646,
#   0.680869351669941,
#   0.7567164179104477,
#   0.6990422396856582,
#   0.7694029850746268,
#   0.7278978388998035,
#   0.7733830845771144,
#   0.7490176817288801,
#   0.7982587064676616,
#   0.7706286836935167,
#   0.7967661691542288,
#   0.7723477406679764,
#   0.8092039800995025,
#   0.7794695481335953,
#   0.8089552238805969,
#   0.7992387033398821,
#   0.8154228855721393,
#   0.8043958742632612,
#   0.8191542288557213,
#   0.8139734774066797,
#   0.8233830845771144,
#   0.8131139489194499,
#   0.8258706467661691,
#   0.8228143418467583,
#   0.8233830845771144,
#   0.830550098231827,
#   0.826865671641791,
#   0.8334970530451866,
#   0.8288557213930348,
#   0.8407416502946954,
#   0.826865671641791,
#   0.8456532416502947,
#   0.8388059701492537,
#   0.8510559921414538,
#   0.8383084577114427,
#   0.8551080550098231,
#   0.8348258706467662,
#   0.855722003929273,
#   0.8338308457711442,
#   0.8506876227897838,
#   0.8345771144278606,
#   0.8587917485265225,
#   0.8320895522388059,
#   0.8656679764243614,
#   0.8405472636815919,
#   0.8579322200392927,
#   0.8330845771144278],
#  [4.966472126645986,
#   4.090364439096024,
#   4.0756422103271035,
#   3.154179191352123,
#   3.403349406826941,
#   2.3912297911904936,
#   2.8812553591016234,
#   1.8679118940486243,
#   2.4603299144911626,
#   1.5464557488166277,
#   2.1245491117063344,
#   1.2836686059610167,
#   1.8346344647683892,
#   1.0587041231975034,
#   1.6184202731241177,
#   0.9788676486976111,
#   1.4877209551851969,
#   0.8900961765009372,
#   1.336762400325717,
#   0.8413700193315004,
#   1.2199626520188243,
#   0.77025987721646,
#   1.113555861582105,
#   0.7426299974841265,
#   1.0832715155977632,
#   0.7053724661840135,
#   1.0183149640007432,
#   0.6911603669399646,
#   0.948343187380282,
#   0.6486911526070306,
#   0.8993167306949734,
#   0.6460909691467807,
#   0.8507852892232198,
#   0.6305418587553857,
#   0.8448935566188251,
#   0.6032998344569064,
#   0.8120716634208304,
#   0.6228279326314949,
#   0.7612712233453579,
#   0.6115693925736259,
#   0.7331999937376128,
#   0.5999542764577996,
#   0.7110292427058831,
#   0.6193211198779778,
#   0.7003602017712558,
#   0.5741117215835818,
#   0.6461374367475656,
#   0.5676027187845897,
#   0.634973161632455,
#   0.5797845407542008,
#   0.6349611526743046,
#   0.5877774620882759,
#   0.6481351104650961,
#   0.5683382884274927,
#   0.5988616328100969,
#   0.5893730422342891,
#   0.5810936466957239,
#   0.569539120672873,
#   0.6139145041020012,
#   0.5863590428633476],
#  [0.16666666666666666,
#   0.3492537313432836,
#   0.4761194029850746,
#   0.5805970149253731,
#   0.645273631840796,
#   0.6990049751243781,
#   0.7393034825870646,
#   0.7567164179104477,
#   0.7694029850746268,
#   0.7733830845771144,
#   0.7982587064676616,
#   0.7967661691542288,
#   0.8092039800995025,
#   0.8089552238805969,
#   0.8154228855721393,
#   0.8191542288557213,
#   0.8233830845771144,
#   0.8258706467661691,
#   0.8233830845771144,
#   0.826865671641791,
#   0.8288557213930348,
#   0.826865671641791,
#   0.8388059701492537,
#   0.8383084577114427,
#   0.8348258706467662,
#   0.8338308457711442,
#   0.8345771144278606,
#   0.8320895522388059,
#   0.8405472636815919,
#   0.8330845771144278])

# %%
# Loading certain model
model_props = {
    'name': 'resnet',
    'dataset': 'FGVC-Aircraft',
    'epochs': 30
}
model_load_path = finetune.format_model_path(model_props['name'],
                                             model_props['dataset'],
                                             model_props['epochs'])
,
state = torch.load(model_load_path)
test_model = finetune.get_model_architecture(model_props['name'])
test_model.load_state_dict(state['model_state_dict'])

optimizer_state_dict = state['optimizer_state_dict']
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-34-4e779458a381> in <module>
#      11 state = torch.load(model_load_path)
#      12 test_model = finetune.get_model_architecture(model_props['name'])
# ---> 13 test_model.load_state_dict(state['model_state_dict'])
#      14
#      15 optimizer_state_dict = state['optimizer_state_dict']
#
# ~\AppData\Roaming\Python\Python38\site-packages\torch\nn\modules\module.py in load_state_dict(self, state_dict, strict)
#    1049
#    1050         if len(error_msgs) > 0:
# -> 1051             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1052                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1053         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for ResNet:
# 	size mismatch for fc.weight: copying a param with shape torch.Size([30, 512]) from checkpoint, the shape in current model is torch.Size([196, 512]).
# 	size mismatch for fc.bias: copying a param with shape torch.Size([30]) from checkpoint, the shape in current model is torch.Size([196]).

# %%
state['val_acc_history']
# Out:
# [tensor(0.1595, device='cuda:0', dtype=torch.float64),
#  tensor(0.3647, device='cuda:0', dtype=torch.float64),
#  tensor(0.5124, device='cuda:0', dtype=torch.float64),
#  tensor(0.5781, device='cuda:0', dtype=torch.float64),
#  tensor(0.6276, device='cuda:0', dtype=torch.float64),
#  tensor(0.6774, device='cuda:0', dtype=torch.float64),
#  tensor(0.6878, device='cuda:0', dtype=torch.float64),
#  tensor(0.7152, device='cuda:0', dtype=torch.float64),
#  tensor(0.7400, device='cuda:0', dtype=torch.float64),
#  tensor(0.7463, device='cuda:0', dtype=torch.float64),
#  tensor(0.7520, device='cuda:0', dtype=torch.float64),
#  tensor(0.7796, device='cuda:0', dtype=torch.float64),
#  tensor(0.7627, device='cuda:0', dtype=torch.float64),
#  tensor(0.7704, device='cuda:0', dtype=torch.float64),
#  tensor(0.7866, device='cuda:0', dtype=torch.float64),
#  tensor(0.7896, device='cuda:0', dtype=torch.float64),
#  tensor(0.7843, device='cuda:0', dtype=torch.float64),
#  tensor(0.7930, device='cuda:0', dtype=torch.float64),
#  tensor(0.8012, device='cuda:0', dtype=torch.float64),
#  tensor(0.8060, device='cuda:0', dtype=torch.float64),
#  tensor(0.8045, device='cuda:0', dtype=torch.float64),
#  tensor(0.8000, device='cuda:0', dtype=torch.float64),
#  tensor(0.8045, device='cuda:0', dtype=torch.float64),
#  tensor(0.8072, device='cuda:0', dtype=torch.float64),
#  tensor(0.8077, device='cuda:0', dtype=torch.float64),
#  tensor(0.8065, device='cuda:0', dtype=torch.float64),
#  tensor(0.8197, device='cuda:0', dtype=torch.float64),
#  tensor(0.8154, device='cuda:0', dtype=torch.float64),
#  tensor(0.8219, device='cuda:0', dtype=torch.float64),
#  tensor(0.8254, device='cuda:0', dtype=torch.float64),
#  tensor(0.8119, device='cuda:0', dtype=torch.float64)]
