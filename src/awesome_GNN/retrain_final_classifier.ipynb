# %%
# %matplotlib inline
# not sure if necessary

# %%
import finetune
import importlib
import torch

# %%
# run this cell when you change stuff in the finetune module, and don't want to restart the notebook's kernel.
importlib.reload(finetune)
# Out:
# <module 'finetune' from '/home/matteo/Documents/Studie/Master/2021-2022/REDI/Project/REDI-utwente/src/awesome_GNN/finetune.py'>

# %%
# Loading certain model
# model_props = {
#     'name': 'resnet',
#     'dataset': 'StanfordCars',
#     'epochs': 30
# }
# model_load_path = finetune.format_model_path(model_props['name'],
#                                              model_props['dataset'],
#                                              model_props['epochs'])
# ,
# state = torch.load(model_load_path)
# model = finetune.get_model_architecture(model_props['name'])
# model.load_state_dict(state['model_state_dict'])
# optimizer_state_dict = state['optimizer_state_dict']

# %%
model_props = {
    'name': 'resnet',
    'dataset': 'FGVC-Aircraft',
    'epochs': 30,
    'occlusion': '0'
}
model_load_path = finetune.format_model_path(model_props['name'],
                                             model_props['dataset'],
                                             model_props['epochs'],
                                             occlusion=model_props['occlusion'])

checkpoint = finetune.load_checkpoint(model_load_path)
info_occ = finetune.get_information_from_checkpoint(checkpoint, plot=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 12>()
#       1 model_props = {
#       2     'name': 'resnet',
#       3     'dataset': 'FGVC-Aircraft',
#       4     'epochs': 30,
#       5     'occlusion': '0'
#       6 }
#       7 model_load_path = finetune.format_model_path(model_props['name'],
#       8                                              model_props['dataset'],
#       9                                              model_props['epochs'],
#      10                                              occlusion=model_props['occlusion'])
# ---> 12 checkpoint = finetune.load_checkpoint(model_load_path)
#      13 info_occ = finetune.get_information_from_checkpoint(checkpoint, plot=True)
#
# File ~/Documents/Studie/Master/2021-2022/REDI/Project/REDI-utwente/src/awesome_GNN/finetune.py:435, in load_checkpoint(path)
#     434 def load_checkpoint(path):
# --> 435     return torch.load(path)
#
# File ~/.pyenv/versions/3.10.0/envs/REDI-3.10.0/lib/python3.10/site-packages/torch/serialization.py:699, in load(f, map_location, pickle_module, **pickle_load_args)
#     696 if 'encoding' not in pickle_load_args.keys():
#     697     pickle_load_args['encoding'] = 'utf-8'
# --> 699 with _open_file_like(f, 'rb') as opened_file:
#     700     if _is_zipfile(opened_file):
#     701         # The zipfile reader is going to advance the current file position.
#     702         # If we want to actually tail call to torch.jit.load, we need to
#     703         # reset back to the original position.
#     704         orig_position = opened_file.tell()
#
# File ~/.pyenv/versions/3.10.0/envs/REDI-3.10.0/lib/python3.10/site-packages/torch/serialization.py:231, in _open_file_like(name_or_buffer, mode)
#     229 def _open_file_like(name_or_buffer, mode):
#     230     if _is_path(name_or_buffer):
# --> 231         return _open_file(name_or_buffer, mode)
#     232     else:
#     233         if 'w' in mode:
#
# File ~/.pyenv/versions/3.10.0/envs/REDI-3.10.0/lib/python3.10/site-packages/torch/serialization.py:212, in _open_file.__init__(self, name, mode)
#     211 def __init__(self, name, mode):
# --> 212     super(_open_file, self).__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/finetuned_models/FGVC-Aircraft/resnet/resnet_FGVC-Aircraft_E30_occ0.pth'

# %%
model_props = {
    'name': 'resnet',
    'dataset': 'FGVC-Aircraft',
    'epochs': 30,
}
model_load_path = finetune.format_model_path(model_props['name'],
                                             model_props['dataset'],
                                             model_props['epochs'],)

checkpoint = finetune.load_checkpoint(model_load_path)
info = finetune.get_information_from_checkpoint(checkpoint, plot=True)

# %%
occ_validation_history = info_occ[2]
normal_validation_history = info[2]

import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(16, 8))
ax.plot(normal_validation_history, color='g', label='normal')
ax.plot(occ_validation_history, color='orange', label='occluded')
ax.legend()

# %%
# Loading certain model
model_props = {
    'name': 'resnet',
    'dataset': 'FGVC-Aircraft',
    'epochs': 30
}
model_load_path = finetune.format_model_path(model_props['name'],
                                             model_props['dataset'],
                                             model_props['epochs'])
,
state = torch.load(model_load_path)
# test_model = finetune.get_model_architecture(model_props['name'])
# test_model.load_state_dict(state['model_state_dict'])
#
# optimizer_state_dict = state['optimizer_state_dict']

state['val_acc_history']
# Out:
# [tensor(0.3966, device='cuda:0', dtype=torch.float64),
#  tensor(0.5578, device='cuda:0', dtype=torch.float64),
#  tensor(0.6439, device='cuda:0', dtype=torch.float64),
#  tensor(0.6379, device='cuda:0', dtype=torch.float64),
#  tensor(0.6980, device='cuda:0', dtype=torch.float64),
#  tensor(0.7201, device='cuda:0', dtype=torch.float64),
#  tensor(0.7322, device='cuda:0', dtype=torch.float64),
#  tensor(0.7651, device='cuda:0', dtype=torch.float64),
#  tensor(0.7700, device='cuda:0', dtype=torch.float64),
#  tensor(0.7819, device='cuda:0', dtype=torch.float64),
#  tensor(0.7765, device='cuda:0', dtype=torch.float64),
#  tensor(0.7721, device='cuda:0', dtype=torch.float64),
#  tensor(0.7915, device='cuda:0', dtype=torch.float64),
#  tensor(0.7807, device='cuda:0', dtype=torch.float64),
#  tensor(0.7883, device='cuda:0', dtype=torch.float64),
#  tensor(0.7814, device='cuda:0', dtype=torch.float64),
#  tensor(0.8002, device='cuda:0', dtype=torch.float64),
#  tensor(0.7919, device='cuda:0', dtype=torch.float64),
#  tensor(0.8009, device='cuda:0', dtype=torch.float64),
#  tensor(0.8044, device='cuda:0', dtype=torch.float64),
#  tensor(0.8008, device='cuda:0', dtype=torch.float64),
#  tensor(0.8089, device='cuda:0', dtype=torch.float64),
#  tensor(0.8018, device='cuda:0', dtype=torch.float64),
#  tensor(0.7988, device='cuda:0', dtype=torch.float64),
#  tensor(0.7987, device='cuda:0', dtype=torch.float64),
#  tensor(0.8032, device='cuda:0', dtype=torch.float64),
#  tensor(0.8038, device='cuda:0', dtype=torch.float64),
#  tensor(0.8084, device='cuda:0', dtype=torch.float64),
#  tensor(0.8077, device='cuda:0', dtype=torch.float64),
#  tensor(0.8081, device='cuda:0', dtype=torch.float64)]

# %%
# Out:
# True
