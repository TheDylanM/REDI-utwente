# %%
# %matplotlib inline
# not sure if necessary

# %%
import finetune
import importlib
import torch

# %%
# run this cell when you change stuff in the finetune module, and don't want to restart the notebook's kernel.
importlib.reload(finetune)
# Out:
# <module 'finetune' from 'C:\\Users\\dylan\\PycharmProjects\\REDI-utwente\\src\\awesome_GNN\\finetune.py'>

# %%
# Loading certain model
# model_props = {
#     'name': 'resnet',
#     'dataset': 'StanfordCars',
#     'epochs': 30
# }
# model_load_path = finetune.format_model_path(model_props['name'],
#                                              model_props['dataset'],
#                                              model_props['epochs'])
# ,
# state = torch.load(model_load_path)
# model = finetune.get_model_architecture(model_props['name'])
# model.load_state_dict(state['model_state_dict'])
# optimizer_state_dict = state['optimizer_state_dict']

# %%
model_props = {
    'name': 'resnet',
    'dataset': 'FGVC-Aircraft',
    'epochs': 30
}
model_load_path = finetune.format_model_path(model_props['name'],
                                             model_props['dataset'],
                                             model_props['epochs'])

checkpoint = finetune.load_checkpoint(model_load_path)
finetune.get_information_from_checkpoint(checkpoint, plot=True)
# Out:
# ([0.30323935212957404,
#   0.39663966396639666,
#   0.44391121775644865,
#   0.5577557755775578,
#   0.55248950209958,
#   0.643864386438644,
#   0.6193761247750449,
#   0.6378637863786379,
#   0.6700659868026394,
#   0.6980198019801981,
#   0.7153569286142771,
#   0.7200720072007202,
#   0.7279544091181763,
#   0.7322232223222322,
#   0.759748050389922,
#   0.7650765076507652,
#   0.774745050989802,
#   0.7700270027002701,
#   0.79124175164967,
#   0.7818781878187819,
#   0.812237552489502,
#   0.7764776477647766,
#   0.8218356328734252,
#   0.7721272127212722,
#   0.8245350929814037,
#   0.7914791479147916,
#   0.8452309538092381,
#   0.7806780678067807,
#   0.8518296340731852,
#   0.7883288328832884,
#   0.8578284343131373,
#   0.7814281428142815,
#   0.8623275344931013,
#   0.8001800180018003,
#   0.8602279544091181,
#   0.791929192919292,
#   0.8614277144571085,
#   0.800930093009301,
#   0.873125374925015,
#   0.8043804380438044,
#   0.8794241151769645,
#   0.8007800780078008,
#   0.8809238152369525,
#   0.808880888088809,
#   0.8920215956808637,
#   0.8018301830183019,
#   0.8923215356928613,
#   0.7988298829882989,
#   0.8797240551889621,
#   0.7986798679867988,
#   0.8923215356928613,
#   0.8031803180318032,
#   0.8908218356328733,
#   0.8037803780378039,
#   0.897120575884823,
#   0.8084308430843085,
#   0.8908218356328733,
#   0.8076807680768078,
#   0.8848230353929213,
#   0.8081308130813082],
#  [2.4434525159997147,
#   1.8154207620039882,
#   1.820859760457195,
#   1.366993915165576,
#   1.4911061868598952,
#   1.1132011678602973,
#   1.2779409954057315,
#   1.0563712394071205,
#   1.1022067150457504,
#   0.9125410309701291,
#   0.9727046475055765,
#   0.8554816563816855,
#   0.9218280556749712,
#   0.8231557115829727,
#   0.8105917741205425,
#   0.7220222628531497,
#   0.7515023399879637,
#   0.7175097686372431,
#   0.712393924155919,
#   0.6853054490386367,
#   0.6345907775009186,
#   0.690192533811756,
#   0.6110120671161579,
#   0.7180248999690423,
#   0.5901139217647308,
#   0.6644778285313039,
#   0.5322255821698572,
#   0.7045701864683214,
#   0.5242105999220683,
#   0.6610054802523964,
#   0.4834361448437065,
#   0.7184502623859036,
#   0.4786265356120909,
#   0.6614972529991536,
#   0.46659992317918825,
#   0.6777321433018644,
#   0.46936895696968106,
#   0.6390919000382024,
#   0.4345686299381102,
#   0.6335947035864653,
#   0.4041901894347283,
#   0.6647399772534763,
#   0.3947127729243122,
#   0.6357829662130968,
#   0.37629711138107996,
#   0.649287152964149,
#   0.3739943172923447,
#   0.6664186047036351,
#   0.3859963671454571,
#   0.6815688316306524,
#   0.3629465607706129,
#   0.6720213753610241,
#   0.3636096007585633,
#   0.6663452116160592,
#   0.33512185056077626,
#   0.6569906600991009,
#   0.35558385149216537,
#   0.6707978598567264,
#   0.3587832585011788,
#   0.646978009088949],
#  [0.39663966396639666,
#   0.5577557755775578,
#   0.643864386438644,
#   0.6378637863786379,
#   0.6980198019801981,
#   0.7200720072007202,
#   0.7322232223222322,
#   0.7650765076507652,
#   0.7700270027002701,
#   0.7818781878187819,
#   0.7764776477647766,
#   0.7721272127212722,
#   0.7914791479147916,
#   0.7806780678067807,
#   0.7883288328832884,
#   0.7814281428142815,
#   0.8001800180018003,
#   0.791929192919292,
#   0.800930093009301,
#   0.8043804380438044,
#   0.8007800780078008,
#   0.808880888088809,
#   0.8018301830183019,
#   0.7988298829882989,
#   0.7986798679867988,
#   0.8031803180318032,
#   0.8037803780378039,
#   0.8084308430843085,
#   0.8076807680768078,
#   0.8081308130813082])

# %%
# Loading certain model
model_props = {
    'name': 'resnet',
    'dataset': 'FGVC-Aircraft',
    'epochs': 30
}
model_load_path = finetune.format_model_path(model_props['name'],
                                             model_props['dataset'],
                                             model_props['epochs'])
,
state = torch.load(model_load_path)
# test_model = finetune.get_model_architecture(model_props['name'])
# test_model.load_state_dict(state['model_state_dict'])
#
# optimizer_state_dict = state['optimizer_state_dict']

state['val_acc_history']
# Out:
# [tensor(0.3966, device='cuda:0', dtype=torch.float64),
#  tensor(0.5578, device='cuda:0', dtype=torch.float64),
#  tensor(0.6439, device='cuda:0', dtype=torch.float64),
#  tensor(0.6379, device='cuda:0', dtype=torch.float64),
#  tensor(0.6980, device='cuda:0', dtype=torch.float64),
#  tensor(0.7201, device='cuda:0', dtype=torch.float64),
#  tensor(0.7322, device='cuda:0', dtype=torch.float64),
#  tensor(0.7651, device='cuda:0', dtype=torch.float64),
#  tensor(0.7700, device='cuda:0', dtype=torch.float64),
#  tensor(0.7819, device='cuda:0', dtype=torch.float64),
#  tensor(0.7765, device='cuda:0', dtype=torch.float64),
#  tensor(0.7721, device='cuda:0', dtype=torch.float64),
#  tensor(0.7915, device='cuda:0', dtype=torch.float64),
#  tensor(0.7807, device='cuda:0', dtype=torch.float64),
#  tensor(0.7883, device='cuda:0', dtype=torch.float64),
#  tensor(0.7814, device='cuda:0', dtype=torch.float64),
#  tensor(0.8002, device='cuda:0', dtype=torch.float64),
#  tensor(0.7919, device='cuda:0', dtype=torch.float64),
#  tensor(0.8009, device='cuda:0', dtype=torch.float64),
#  tensor(0.8044, device='cuda:0', dtype=torch.float64),
#  tensor(0.8008, device='cuda:0', dtype=torch.float64),
#  tensor(0.8089, device='cuda:0', dtype=torch.float64),
#  tensor(0.8018, device='cuda:0', dtype=torch.float64),
#  tensor(0.7988, device='cuda:0', dtype=torch.float64),
#  tensor(0.7987, device='cuda:0', dtype=torch.float64),
#  tensor(0.8032, device='cuda:0', dtype=torch.float64),
#  tensor(0.8038, device='cuda:0', dtype=torch.float64),
#  tensor(0.8084, device='cuda:0', dtype=torch.float64),
#  tensor(0.8077, device='cuda:0', dtype=torch.float64),
#  tensor(0.8081, device='cuda:0', dtype=torch.float64)]

# %%
state['val_acc_history']
# Out:
# [tensor(0.3966, device='cuda:0', dtype=torch.float64),
#  tensor(0.5578, device='cuda:0', dtype=torch.float64),
#  tensor(0.6439, device='cuda:0', dtype=torch.float64),
#  tensor(0.6379, device='cuda:0', dtype=torch.float64),
#  tensor(0.6980, device='cuda:0', dtype=torch.float64),
#  tensor(0.7201, device='cuda:0', dtype=torch.float64),
#  tensor(0.7322, device='cuda:0', dtype=torch.float64),
#  tensor(0.7651, device='cuda:0', dtype=torch.float64),
#  tensor(0.7700, device='cuda:0', dtype=torch.float64),
#  tensor(0.7819, device='cuda:0', dtype=torch.float64),
#  tensor(0.7765, device='cuda:0', dtype=torch.float64),
#  tensor(0.7721, device='cuda:0', dtype=torch.float64),
#  tensor(0.7915, device='cuda:0', dtype=torch.float64),
#  tensor(0.7807, device='cuda:0', dtype=torch.float64),
#  tensor(0.7883, device='cuda:0', dtype=torch.float64),
#  tensor(0.7814, device='cuda:0', dtype=torch.float64),
#  tensor(0.8002, device='cuda:0', dtype=torch.float64),
#  tensor(0.7919, device='cuda:0', dtype=torch.float64),
#  tensor(0.8009, device='cuda:0', dtype=torch.float64),
#  tensor(0.8044, device='cuda:0', dtype=torch.float64),
#  tensor(0.8008, device='cuda:0', dtype=torch.float64),
#  tensor(0.8089, device='cuda:0', dtype=torch.float64),
#  tensor(0.8018, device='cuda:0', dtype=torch.float64),
#  tensor(0.7988, device='cuda:0', dtype=torch.float64),
#  tensor(0.7987, device='cuda:0', dtype=torch.float64),
#  tensor(0.8032, device='cuda:0', dtype=torch.float64),
#  tensor(0.8038, device='cuda:0', dtype=torch.float64),
#  tensor(0.8084, device='cuda:0', dtype=torch.float64),
#  tensor(0.8077, device='cuda:0', dtype=torch.float64),
#  tensor(0.8081, device='cuda:0', dtype=torch.float64)]
